# %% [markdown]
# ### This notebook is for testing sorting algorithms, code to be moved to sort.py

# %%
from array import array
import numpy as np
# use numpy.array?

# %%
# see "Sorting" lecture slides, slide 90
def merge(arr: list, start: int, mid: int, end: int):
    n1 = mid - start + 1
    n2 = end - mid
    X, Y = [], []
    [X.append(arr[start + i]) for i in range(n1)]
    [Y.append(arr[mid + 1 + j]) for j in range(n2)]
    # merge the arrays X and Y into arr
    i, j, k = 0, 0, start
    while i < n1 & j < n2:
        if X[i] <= Y[j]:
            arr[k] = X[i]
            i += 1
        else:
            arr[k] = Y[j]
            j += 1
        k += 1
    # When we run out of elements in either X or Y append the remaining elements
    while i < n1:
        arr[k] = X[i]
        i += 1
        k += 1
    while j < n2:
        arr[k] = Y[j]
        j += 1
        k += 1

# %%
# algorithm from sorting review slides and lecture slides (slide 89) 
# merge sort takes in a one-dimensional array and returns the sorted one-dimension array
def merge_sort(arr: list, start: int, end: int):
    if start < end:
        mid = start + round((end - start) / 2) # python does not automatically recognize end and start as integers
        # divide arr into subarrays
        merge_sort(arr, start, mid)
        merge_sort(arr, mid + 1, end)

        # merge the sorted subarrays
        merge(arr, start, mid, end)

# %%
def partition(arr, low, high) -> int:
    pivot = arr[low]
    up, down = low, high
    while up < down:
        for j in range(up, high):
            if arr[up] > pivot:
                break
            up += 1
        for j in range(high, low, -1):
            if arr[down] < pivot:
                break
            down -= 1
        if up < down:
            # equivalent to C++ swap()
            up_val = arr[up]
            arr[up] = arr[down]
            arr[down] = up_val
    low_val = arr[low]
    arr[low] = arr[down]
    arr[down] = low_val
    return down

# %%
def quick_sort(arr:list, low:int, high:int):
    if low < high:
        pivot = partition(arr, low, high)
        quick_sort(arr, low, pivot - 1)
        quick_sort(arr, pivot + 1, high)

# %% [markdown]
# ## Apply merge sort, quick sort to string columns: gender, location

# %%
import dataset
import pandas as pd

# %%
selection = "gender"
data = dataset.load_data(selection)
if selection == "gender":
    # https://stackoverflow.com/questions/38088652/pandas-convert-categories-to-numbers
    data = pd.Categorical(data)

# %%
print(data)
# Out:
# None

# %%
# Here we see that the data are converted to numpy array with 0: female, 1: male, 2: other
print(type(data.codes))
print(set(data))
print(set(data.codes))
# Out:
# <class 'numpy.ndarray'>
# {'Female', 'Male', 'Other'}
# {np.int8(0), np.int8(1), np.int8(2)}

# %%
# We can pass in data.codes to merge sort and quick sort
merge_sort(data.codes, 0, len(data.codes) -1)
quick_sort(data.codes, 0, len(data.codes) -1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 # We can pass in data.codes to merge sort and quick sort
# ----> 2 merge_sort(data.codes, 0, len(data.codes) -1)
#       3 quick_sort(data.codes, 0, len(data.codes) -1)
#
# Cell In[14], line 7, in merge_sort(arr, start, end)
#       5 mid = start + round((end - start) / 2) # python does not automatically recognize end and start as integers
#       6 # divide arr into subarrays
# ----> 7 merge_sort(arr, start, mid)
#       8 merge_sort(arr, mid + 1, end)
#      10 # merge the sorted subarrays
#
# Cell In[14], line 7, in merge_sort(arr, start, end)
#       5 mid = start + round((end - start) / 2) # python does not automatically recognize end and start as integers
#       6 # divide arr into subarrays
# ----> 7 merge_sort(arr, start, mid)
#       8 merge_sort(arr, mid + 1, end)
#      10 # merge the sorted subarrays
#
#     [... skipping similar frames: merge_sort at line 7 (14 times)]
#
# Cell In[14], line 7, in merge_sort(arr, start, end)
#       5 mid = start + round((end - start) / 2) # python does not automatically recognize end and start as integers
#       6 # divide arr into subarrays
# ----> 7 merge_sort(arr, start, mid)
#       8 merge_sort(arr, mid + 1, end)
#      10 # merge the sorted subarrays
#
# Cell In[14], line 11, in merge_sort(arr, start, end)
#       8 merge_sort(arr, mid + 1, end)
#      10 # merge the sorted subarrays
# ---> 11 merge(arr, start, mid, end)
#
# Cell In[13], line 20, in merge(arr, start, mid, end)
#      18 # When we run out of elements in either X or Y append the remaining elements
#      19 while i < n1:
# ---> 20     arr[k] = X[i]
#      21     i += 1
#      22     k += 1
#
# ValueError: assignment destination is read-only

# %%
# Out:
# {np.int8(0), np.int8(1), np.int8(2)}

# %%
data['codes'] = data.codes
# type(data.codes)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data['codes'] = data.codes
#       2 # type(data.codes)
#
# File ~/anaconda3/envs/p2_env/lib/python3.14/site-packages/pandas/core/arrays/_mixins.py:272, in NDArrayBackedExtensionArray.__setitem__(self, key, value)
#     269     raise ValueError("Cannot modify read-only array")
#     271 key = check_array_indexer(self, key)
# --> 272 value = self._validate_setitem_value(value)
#     273 self._ndarray[key] = value
#
# File ~/anaconda3/envs/p2_env/lib/python3.14/site-packages/pandas/core/arrays/categorical.py:1651, in Categorical._validate_setitem_value(self, value)
#    1648 def _validate_setitem_value(self, value):
#    1649     if not is_hashable(value):
#    1650         # wrap scalars and hashable-listlikes in list
# -> 1651         return self._validate_listlike(value)
#    1652     else:
#    1653         return self._validate_scalar(value)
#
# File ~/anaconda3/envs/p2_env/lib/python3.14/site-packages/pandas/core/arrays/categorical.py:2407, in Categorical._validate_listlike(self, value)
#    2404 # no assignments of values not in categories, but it's always ok to set
#    2405 # something to np.nan
#    2406 if len(to_add) and not isna(to_add).all():
# -> 2407     raise TypeError(
#    2408         "Cannot setitem on a Categorical with a new "
#    2409         "category, set the categories first"
#    2410     )
#    2412 codes = self.categories.get_indexer(value)
#    2413 return codes.astype(self._ndarray.dtype, copy=False)
#
# TypeError: Cannot setitem on a Categorical with a new category, set the categories first

# %% [markdown]
# ### Test whether sorting algorithms work as expected

# %%
data_test = [15,0,5,6,11,3,1]
quick_sort(data_test, 0, len(data_test)-1)
data_test
# Out:
# [0, 1, 3, 5, 6, 11, 15]

# %%
merge_sort(data_test, 0, len(data_test) -1 )
data_test
# Out:
# [0, 1, 3, 5, 6, 11, 15]

# %%
type(data_test)
# Out:
# list

# %%
# Here we see that data is a list of digits represented as strings. We need digits represented as integers.
data = dataset.load_data("age")
print(type(data.copy()), type(data))
data.copy()[:10]
# Out:
# <class 'list'> <class 'list'>
# ['32', '29', '18', '41', '52', '66', '49', '15', '51', '42']

# %%
# https://www.geeksforgeeks.org/python/python-converting-all-strings-in-list-to-integers/
data = list(map(int, data))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 2
#       1 # https://www.geeksforgeeks.org/python/python-converting-all-strings-in-list-to-integers/
# ----> 2 data = list(map(int, data))
#
# ValueError: invalid literal for int() with base 10: '1.32'

# %%
data = list(map(float, data))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 data = list(map(float, data))
#
# ValueError: invalid literal for int() with base 10: '0.48'

# %%
data = merge_sort(data, 0, len(data)-1)

# %%
print(data)

# %%
import dataset

# %%
data = dataset.load_data("age")

# %%
type(data.copy())
data.copy()[:10]
len(data.copy())
# Out:
# 100000

# %%
for j in range(4, 2,-1):
    print(j)
# Out:
# 4
# 3

# %% [markdown]
# Comparing merge sort, quick sort to native python functions

# %%
data = dataset.load_data("age")
data[:10]
# Out:
# ['32', '29', '18', '41', '52', '66', '49', '15', '51', '42']

# %%
data.sort()
min(data), max(data)
# Out:
# ('0.08', '9')

# %% [markdown]
# ### Generate a random dataset of 100,000 datapoints

# %%
# def mergeSortNew(arr: np.ndarray) -> np.ndarray:
#    return np.array([1,2,3])

# %%
# nums = array('h', [9,8,6,5,7,3,1,2])

# %%
# nums_sorted = sorted(nums)

# %%
# nums_sorted
# Out:
# [1, 2, 3, 5, 6, 7, 8, 9]
